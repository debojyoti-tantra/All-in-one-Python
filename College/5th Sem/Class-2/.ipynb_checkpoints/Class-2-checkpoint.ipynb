# %% [markdown]
# # Curve fitting using numpy and scipy

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
# given
x = [1,2,3,4,5,6]
y = [7,25,30,45,45,60]

# %%
def f(x, a, b):
    z = a*x + b
    return z

# %%
par, err = curve_fit(f, x, y)
a = par[0]
b = par[1]
print("slope is: ", a, "y-intercept is: ", b)
# Out:
# slope is:  9.714285714304722 y-intercept is:  1.3333333333340616

# %%
x_new = np.linspace(1, 6, 100)
y_new = f(x_new, a, b)

plt.plot(x, y, "o")

plt.plot(x_new, y_new)

plt.grid()
plt.show()

# %% [markdown]
# # Curve fitting using only numpy packege

# %%
x1 = np.array(x)
y1 = np.array(y)

m,c = np.polyfit(x, y, 1)

print("slope is: ", m, "y-intercept is: ", c)
# Out:
# slope is:  9.71428571428571 y-intercept is:  1.3333333333333368

# %%
x1_new = np.linspace(1, 6, 100)
y1_new = m*x1_new + c

print(x1_new, y1_new)
# Out:
# [1.         1.05050505 1.1010101  1.15151515 1.2020202  1.25252525
#  1.3030303  1.35353535 1.4040404  1.45454545 1.50505051 1.55555556
#  1.60606061 1.65656566 1.70707071 1.75757576 1.80808081 1.85858586
#  1.90909091 1.95959596 2.01010101 2.06060606 2.11111111 2.16161616
#  2.21212121 2.26262626 2.31313131 2.36363636 2.41414141 2.46464646
#  2.51515152 2.56565657 2.61616162 2.66666667 2.71717172 2.76767677
#  2.81818182 2.86868687 2.91919192 2.96969697 3.02020202 3.07070707
#  3.12121212 3.17171717 3.22222222 3.27272727 3.32323232 3.37373737
#  3.42424242 3.47474747 3.52525253 3.57575758 3.62626263 3.67676768
#  3.72727273 3.77777778 3.82828283 3.87878788 3.92929293 3.97979798
#  4.03030303 4.08080808 4.13131313 4.18181818 4.23232323 4.28282828
#  4.33333333 4.38383838 4.43434343 4.48484848 4.53535354 4.58585859
#  4.63636364 4.68686869 4.73737374 4.78787879 4.83838384 4.88888889
#  4.93939394 4.98989899 5.04040404 5.09090909 5.14141414 5.19191919
#  5.24242424 5.29292929 5.34343434 5.39393939 5.44444444 5.49494949
#  5.54545455 5.5959596  5.64646465 5.6969697  5.74747475 5.7979798
#  5.84848485 5.8989899  5.94949495 6.        ] [11.04761905 11.53823954 12.02886003 12.51948052 13.01010101 13.5007215
#  13.99134199 14.48196248 14.97258297 15.46320346 15.95382395 16.44444444
#  16.93506494 17.42568543 17.91630592 18.40692641 18.8975469  19.38816739
#  19.87878788 20.36940837 20.86002886 21.35064935 21.84126984 22.33189033
#  22.82251082 23.31313131 23.8037518  24.29437229 24.78499278 25.27561328
#  25.76623377 26.25685426 26.74747475 27.23809524 27.72871573 28.21933622
#  28.70995671 29.2005772  29.69119769 30.18181818 30.67243867 31.16305916
#  31.65367965 32.14430014 32.63492063 33.12554113 33.61616162 34.10678211
#  34.5974026  35.08802309 35.57864358 36.06926407 36.55988456 37.05050505
#  37.54112554 38.03174603 38.52236652 39.01298701 39.5036075  39.99422799
#  40.48484848 40.97546898 41.46608947 41.95670996 42.44733045 42.93795094
#  43.42857143 43.91919192 44.40981241 44.9004329  45.39105339 45.88167388
#  46.37229437 46.86291486 47.35353535 47.84415584 48.33477633 48.82539683
#  49.31601732 49.80663781 50.2972583  50.78787879 51.27849928 51.76911977
#  52.25974026 52.75036075 53.24098124 53.73160173 54.22222222 54.71284271
#  55.2034632  55.69408369 56.18470418 56.67532468 57.16594517 57.65656566
#  58.14718615 58.63780664 59.12842713 59.61904762]

# %%
plt.plot(x1, y1, "o")

plt.plot(x1_new, y1_new)

plt.grid()
plt.show()
